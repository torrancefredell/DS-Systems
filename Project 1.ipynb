# %% [markdown]
# # ETL Data Processor - DS2002 Project 1

# %% [markdown]
# Deliverable: Author a segment of an ETL pipeline that will ingest or process raw data. Submit a URL to a GitHub repository for your solution. In python you’ll need to know how to open files, iterate files, pattern match and output files.

# %% [markdown]
# Due date: Oct 31st, 11:59 PM

# %% [markdown]
# Benchmarks: data processor should be able to ingest a pre-defined data source and perform at least 3 of these operations:
# 1. Fetch / download / retrieve a remote data file by URL (API call like we did
# in class), or ingest a local file that you have downloaded from
# somewhere…like in a CSV format. Suggestions for remote data sources
# are listed at the end of this document on our Github page as we went
# through in class.
# 2. Convert the general format and data structure of the data source (from
# JSON to CSV, from CSV to JSON, from JSON into a SQL database table,
# etc. I want the option to convert any source to any target. So, if I get a
# CSV as an input, I want the user to choose an output)
# 3. Modify the number of columns from the source to the destination,
# reducing or adding columns so that you transform it with something
# else…you can make up whatever it is…like date changes…or mash up
# two columns…it’s up to you.
# 4. The converted (new) file should be written to disk (local file) or written to a
# SQL database like SQL Lite
# 5. Generate a brief summary of the data file ingestion after it has processed
# and output it to the user including:
#      1. Number of records
#      2. Number of columns
# <br>The processor should produce informative errors should it be unable to complete
# an operation. (Try / Catch with error messages, not file exists…just pick any
# error.)

# %%
# imports
import json
import requests
import pandas as pd
import csv
from IPython.core.display import HTML
import sqlite3
from datetime import datetime
import numpy as np

# %%
print("Enter your client access token: ")
# mine is 'UUsrN0YdG7AF2g7G_YvYwfZnCf_xCeq71vywHCILsLuk4GZYuzfVHbiWJlHboKCc' feel free to use it for this 
client_access_token = input()
# Out:
# Enter your client access token:
# UUsrN0YdG7AF2g7G_YvYwfZnCf_xCeq71vywHCILsLuk4GZYuzfVHbiWJlHboKCc

# %%
print("Which artist would you like to search? ")
artist = input()
# Out:
# Which artist would you like to search?
# the chicks

# %%
# base url (genius)
search_url = f"http://api.genius.com/search?q={artist}&access_token={client_access_token}"
search_url
# Out:
# 'http://api.genius.com/search?q=the chicks&access_token=UUsrN0YdG7AF2g7G_YvYwfZnCf_xCeq71vywHCILsLuk4GZYuzfVHbiWJlHboKCc'

# %%
def get_api_response(url, response_type):
    try:
        response = requests.get(url)
        response.raise_for_status()
    
    except requests.exceptions.HTTPError as errh:
        return "An Http Error occurred: " + repr(errh)
    except requests.exceptions.ConnectionError as errc:
        return "An Error Connecting to the API occurred: " + repr(errc)
    except requests.exceptions.Timeout as errt:
        return "A Timeout Error occurred: " + repr(errt)
    except requests.exceptions.RequestException as err:
        return "An Unknown Error occurred: " + repr(err)

    if response_type == 'json':
        result = json.dumps(response.json(), sort_keys=True, indent=4)
    else:
        result = "An unhandled error has occurred!"
        
    return result

# %%
r = requests.request("GET", search_url)
#r.content
get_api_response(search_url, json)
genius_json = r.json()
genius_json
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 5,
#      'api_path': '/songs/122323',
#      'artist_names': 'The Chicks',
#      'full_title': "Travelin' Soldier by\xa0The\xa0Chicks",
#      'header_image_thumbnail_url': 'https://images.genius.com/aa6aa23a35a330ff54ad6b4f9a903970.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/aa6aa23a35a330ff54ad6b4f9a903970.1000x1000x1.jpg',
#      'id': 122323,
#      'language': 'en',
#      'lyrics_owner_id': 132337,
#      'lyrics_state': 'complete',
#      'path': '/The-chicks-travelin-soldier-lyrics',
#      'pyongs_count': 13,
#      'relationships_index_url': 'https://genius.com/The-chicks-travelin-soldier-sample',
#      'release_date_components': {'year': 2002, 'month': 7, 'day': 26},
#      'release_date_for_display': 'July 26, 2002',
#      'release_date_with_abbreviated_month_for_display': 'Jul. 26, 2002',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/ad9f3f046b17b05868529aefdb2549c7.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/ad9f3f046b17b05868529aefdb2549c7.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 87424},
#      'title': 'Travelin’ Soldier',
#      'title_with_featured': "Travelin' Soldier",
#      'url': 'https://genius.com/The-chicks-travelin-soldier-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/24366',
#       'header_image_url': 'https://images.genius.com/ec7ef9e21398df992cb97508a9888383.1000x333x1.jpg',
#       'id': 24366,
#       'image_url': 'https://images.genius.com/8fed4750f08a5aceea55e3165e00dcca.400x400x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Chicks',
#       'url': 'https://genius.com/artists/The-chicks'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 7,
#      'api_path': '/songs/4889106',
#      'artist_names': 'The Chicks',
#      'full_title': 'Gaslighter by\xa0The\xa0Chicks',
#      'header_image_thumbnail_url': 'https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.1000x1000x1.jpg',
#      'id': 4889106,
#      'language': 'en',
#      'lyrics_owner_id': 1599419,
#      'lyrics_state': 'complete',
#      'path': '/The-chicks-gaslighter-lyrics',
#      'pyongs_count': 1,
#      'relationships_index_url': 'https://genius.com/The-chicks-gaslighter-sample',
#      'release_date_components': {'year': 2020, 'month': 3, 'day': 4},
#      'release_date_for_display': 'March 4, 2020',
#      'release_date_with_abbreviated_month_for_display': 'Mar. 4, 2020',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 101365},
#      'title': 'Gaslighter',
#      'title_with_featured': 'Gaslighter',
#      'url': 'https://genius.com/The-chicks-gaslighter-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/24366',
#       'header_image_url': 'https://images.genius.com/ec7ef9e21398df992cb97508a9888383.1000x333x1.jpg',
#       'id': 24366,
#       'image_url': 'https://images.genius.com/8fed4750f08a5aceea55e3165e00dcca.400x400x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Chicks',
#       'url': 'https://genius.com/artists/The-chicks'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 10,
#      'api_path': '/songs/504153',
#      'artist_names': 'The Chicks',
#      'full_title': 'Not Ready to Make Nice by\xa0The\xa0Chicks',
#      'header_image_thumbnail_url': 'https://images.genius.com/5c554c027ff57641658033803588c7d3.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/5c554c027ff57641658033803588c7d3.1000x1000x1.jpg',
#      'id': 504153,
#      'language': 'en',
#      'lyrics_owner_id': 275094,
#      'lyrics_state': 'complete',
#      'path': '/The-chicks-not-ready-to-make-nice-lyrics',
#      'pyongs_count': 7,
#      'relationships_index_url': 'https://genius.com/The-chicks-not-ready-to-make-nice-sample',
#      'release_date_components': {'year': 2006, 'month': 3, 'day': 24},
#      'release_date_for_display': 'March 24, 2006',
#      'release_date_with_abbreviated_month_for_display': 'Mar. 24, 2006',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/6782708e69d4b6354d61e51c6fd7e571.300x264x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/6782708e69d4b6354d61e51c6fd7e571.600x528x1.jpg',
#      'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 58976},
#      'title': 'Not Ready to Make Nice',
#      'title_with_featured': 'Not Ready to Make Nice',
#      'url': 'https://genius.com/The-chicks-not-ready-to-make-nice-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/24366',
#       'header_image_url': 'https://images.genius.com/ec7ef9e21398df992cb97508a9888383.1000x333x1.jpg',
#       'id': 24366,
#       'image_url': 'https://images.genius.com/8fed4750f08a5aceea55e3165e00dcca.400x400x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Chicks',
#       'url': 'https://genius.com/artists/The-chicks'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 12,
#      'api_path': '/songs/5692376',
#      'artist_names': 'The Chicks',
#      'full_title': 'March March by\xa0The\xa0Chicks',
#      'header_image_thumbnail_url': 'https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.1000x1000x1.jpg',
#      'id': 5692376,
#      'language': 'en',
#      'lyrics_owner_id': 2667162,
#      'lyrics_state': 'complete',
#      'path': '/The-chicks-march-march-lyrics',
#      'pyongs_count': 2,
#      'relationships_index_url': 'https://genius.com/The-chicks-march-march-sample',
#      'release_date_components': {'year': 2020, 'month': 6, 'day': 25},
#      'release_date_for_display': 'June 25, 2020',
#      'release_date_with_abbreviated_month_for_display': 'Jun. 25, 2020',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 57586},
#      'title': 'March March',
#      'title_with_featured': 'March March',
#      'url': 'https://genius.com/The-chicks-march-march-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/24366',
#       'header_image_url': 'https://images.genius.com/ec7ef9e21398df992cb97508a9888383.1000x333x1.jpg',
#       'id': 24366,
#       'image_url': 'https://images.genius.com/8fed4750f08a5aceea55e3165e00dcca.400x400x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Chicks',
#       'url': 'https://genius.com/artists/The-chicks'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 4,
#      'api_path': '/songs/610393',
#      'artist_names': 'The Chicks',
#      'full_title': 'Landslide by\xa0The\xa0Chicks',
#      'header_image_thumbnail_url': 'https://images.genius.com/600036fad1fbd1f9fcf213ca936fdc2c.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/600036fad1fbd1f9fcf213ca936fdc2c.1000x1000x1.jpg',
#      'id': 610393,
#      'language': 'en',
#      'lyrics_owner_id': 851743,
#      'lyrics_state': 'complete',
#      'path': '/The-chicks-landslide-lyrics',
#      'pyongs_count': 5,
#      'relationships_index_url': 'https://genius.com/The-chicks-landslide-sample',
#      'release_date_components': {'year': 2002, 'month': 9, 'day': 2},
#      'release_date_for_display': 'September 2, 2002',
#      'release_date_with_abbreviated_month_for_display': 'Sep. 2, 2002',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/5ac3dea65ba38fae325250ad95b475c2.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/5ac3dea65ba38fae325250ad95b475c2.512x512x1.jpg',
#      'stats': {'unreviewed_annotations': 3, 'hot': False, 'pageviews': 31199},
#      'title': 'Landslide',
#      'title_with_featured': 'Landslide',
#      'url': 'https://genius.com/The-chicks-landslide-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/24366',
#       'header_image_url': 'https://images.genius.com/ec7ef9e21398df992cb97508a9888383.1000x333x1.jpg',
#       'id': 24366,
#       'image_url': 'https://images.genius.com/8fed4750f08a5aceea55e3165e00dcca.400x400x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Chicks',
#       'url': 'https://genius.com/artists/The-chicks'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 0,
#      'api_path': '/songs/607161',
#      'artist_names': 'The Chicks',
#      'full_title': 'You Were Mine by\xa0The\xa0Chicks',
#      'header_image_thumbnail_url': 'https://images.genius.com/5934aea6e3ec237a9ff5b908c1ecc2f8.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/5934aea6e3ec237a9ff5b908c1ecc2f8.1000x1000x1.jpg',
#      'id': 607161,
#      'language': 'en',
#      'lyrics_owner_id': 851743,
#      'lyrics_state': 'complete',
#      'path': '/The-chicks-you-were-mine-lyrics',
#      'pyongs_count': 1,
#      'relationships_index_url': 'https://genius.com/The-chicks-you-were-mine-sample',
#      'release_date_components': {'year': 1998, 'month': 12, 'day': 7},
#      'release_date_for_display': 'December 7, 1998',
#      'release_date_with_abbreviated_month_for_display': 'Dec. 7, 1998',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/e9542c9fb722939e12cb9e812f582874.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/e9542c9fb722939e12cb9e812f582874.300x300x1.jpg',
#      'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 28090},
#      'title': 'You Were Mine',
#      'title_with_featured': 'You Were Mine',
#      'url': 'https://genius.com/The-chicks-you-were-mine-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/24366',
#       'header_image_url': 'https://images.genius.com/ec7ef9e21398df992cb97508a9888383.1000x333x1.jpg',
#       'id': 24366,
#       'image_url': 'https://images.genius.com/8fed4750f08a5aceea55e3165e00dcca.400x400x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Chicks',
#       'url': 'https://genius.com/artists/The-chicks'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 3,
#      'api_path': '/songs/5660793',
#      'artist_names': 'The Chicks',
#      'full_title': 'Tights on My Boat by\xa0The\xa0Chicks',
#      'header_image_thumbnail_url': 'https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.1000x1000x1.jpg',
#      'id': 5660793,
#      'language': 'en',
#      'lyrics_owner_id': 4921876,
#      'lyrics_state': 'complete',
#      'path': '/The-chicks-tights-on-my-boat-lyrics',
#      'pyongs_count': None,
#      'relationships_index_url': 'https://genius.com/The-chicks-tights-on-my-boat-sample',
#      'release_date_components': {'year': 2020, 'month': 7, 'day': 17},
#      'release_date_for_display': 'July 17, 2020',
#      'release_date_with_abbreviated_month_for_display': 'Jul. 17, 2020',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.1000x1000x1.jpg',
#      'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 25344},
#      'title': 'Tights on My Boat',
#      'title_with_featured': 'Tights on My Boat',
#      'url': 'https://genius.com/The-chicks-tights-on-my-boat-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/24366',
#       'header_image_url': 'https://images.genius.com/ec7ef9e21398df992cb97508a9888383.1000x333x1.jpg',
#       'id': 24366,
#       'image_url': 'https://images.genius.com/8fed4750f08a5aceea55e3165e00dcca.400x400x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Chicks',
#       'url': 'https://genius.com/artists/The-chicks'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 13,
#      'api_path': '/songs/86522',
#      'artist_names': 'The Chicks',
#      'full_title': 'Goodbye Earl by\xa0The\xa0Chicks',
#      'header_image_thumbnail_url': 'https://images.genius.com/9fcdce21d8766bff64dc9d0832be3880.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/9fcdce21d8766bff64dc9d0832be3880.1000x1000x1.jpg',
#      'id': 86522,
#      'language': 'en',
#      'lyrics_owner_id': 123252,
#      'lyrics_state': 'complete',
#      'path': '/The-chicks-goodbye-earl-lyrics',
#      'pyongs_count': 2,
#      'relationships_index_url': 'https://genius.com/The-chicks-goodbye-earl-sample',
#      'release_date_components': {'year': 2000, 'month': 2, 'day': 29},
#      'release_date_for_display': 'February 29, 2000',
#      'release_date_with_abbreviated_month_for_display': 'Feb. 29, 2000',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/b7ae10025c23981e4dae247d3caabe47.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/b7ae10025c23981e4dae247d3caabe47.500x500x1.jpg',
#      'stats': {'unreviewed_annotations': 4, 'hot': False, 'pageviews': 38317},
#      'title': 'Goodbye Earl',
#      'title_with_featured': 'Goodbye Earl',
#      'url': 'https://genius.com/The-chicks-goodbye-earl-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/24366',
#       'header_image_url': 'https://images.genius.com/ec7ef9e21398df992cb97508a9888383.1000x333x1.jpg',
#       'id': 24366,
#       'image_url': 'https://images.genius.com/8fed4750f08a5aceea55e3165e00dcca.400x400x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Chicks',
#       'url': 'https://genius.com/artists/The-chicks'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 5,
#      'api_path': '/songs/607128',
#      'artist_names': 'The Chicks',
#      'full_title': 'Cowboy Take Me Away by\xa0The\xa0Chicks',
#      'header_image_thumbnail_url': 'https://images.genius.com/5bacd64f66993fe06b87a5bd53b5c398.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/5bacd64f66993fe06b87a5bd53b5c398.470x470x1.jpg',
#      'id': 607128,
#      'language': 'en',
#      'lyrics_owner_id': 851743,
#      'lyrics_state': 'complete',
#      'path': '/The-chicks-cowboy-take-me-away-lyrics',
#      'pyongs_count': 3,
#      'relationships_index_url': 'https://genius.com/The-chicks-cowboy-take-me-away-sample',
#      'release_date_components': {'year': 1999, 'month': 8, 'day': 31},
#      'release_date_for_display': 'August 31, 1999',
#      'release_date_with_abbreviated_month_for_display': 'Aug. 31, 1999',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/5bacd64f66993fe06b87a5bd53b5c398.300x300x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/5bacd64f66993fe06b87a5bd53b5c398.470x470x1.jpg',
#      'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 22504},
#      'title': 'Cowboy Take Me Away',
#      'title_with_featured': 'Cowboy Take Me Away',
#      'url': 'https://genius.com/The-chicks-cowboy-take-me-away-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/24366',
#       'header_image_url': 'https://images.genius.com/ec7ef9e21398df992cb97508a9888383.1000x333x1.jpg',
#       'id': 24366,
#       'image_url': 'https://images.genius.com/8fed4750f08a5aceea55e3165e00dcca.400x400x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Chicks',
#       'url': 'https://genius.com/artists/The-chicks'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/95118',
#      'artist_names': 'The Chicks',
#      'full_title': 'Wide Open Spaces by\xa0The\xa0Chicks',
#      'header_image_thumbnail_url': 'https://images.genius.com/9b68699b8fd851dec84e1e73aa4c290d.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/9b68699b8fd851dec84e1e73aa4c290d.1000x1000x1.jpg',
#      'id': 95118,
#      'language': 'en',
#      'lyrics_owner_id': 133371,
#      'lyrics_state': 'complete',
#      'path': '/The-chicks-wide-open-spaces-lyrics',
#      'pyongs_count': 1,
#      'relationships_index_url': 'https://genius.com/The-chicks-wide-open-spaces-sample',
#      'release_date_components': {'year': 1998, 'month': 1, 'day': 27},
#      'release_date_for_display': 'January 27, 1998',
#      'release_date_with_abbreviated_month_for_display': 'Jan. 27, 1998',
#      'song_art_image_thumbnail_url': 'https://images.genius.com/48c5e3a0c2d3a5f2402a9547d7e3f54b.300x302x1.jpg',
#      'song_art_image_url': 'https://images.genius.com/48c5e3a0c2d3a5f2402a9547d7e3f54b.310x312x1.jpg',
#      'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 15936},
#      'title': 'Wide Open Spaces',
#      'title_with_featured': 'Wide Open Spaces',
#      'url': 'https://genius.com/The-chicks-wide-open-spaces-lyrics',
#      'featured_artists': [],
#      'primary_artist': {'api_path': '/artists/24366',
#       'header_image_url': 'https://images.genius.com/ec7ef9e21398df992cb97508a9888383.1000x333x1.jpg',
#       'id': 24366,
#       'image_url': 'https://images.genius.com/8fed4750f08a5aceea55e3165e00dcca.400x400x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'The Chicks',
#       'url': 'https://genius.com/artists/The-chicks'}}}]}}

# %%
genius_json['response']['hits'][0]
# exploring
# Out:
# {'highlights': [],
#  'index': 'song',
#  'type': 'song',
#  'result': {'annotation_count': 5,
#   'api_path': '/songs/122323',
#   'artist_names': 'The Chicks',
#   'full_title': "Travelin' Soldier by\xa0The\xa0Chicks",
#   'header_image_thumbnail_url': 'https://images.genius.com/aa6aa23a35a330ff54ad6b4f9a903970.300x300x1.jpg',
#   'header_image_url': 'https://images.genius.com/aa6aa23a35a330ff54ad6b4f9a903970.1000x1000x1.jpg',
#   'id': 122323,
#   'language': 'en',
#   'lyrics_owner_id': 132337,
#   'lyrics_state': 'complete',
#   'path': '/The-chicks-travelin-soldier-lyrics',
#   'pyongs_count': 13,
#   'relationships_index_url': 'https://genius.com/The-chicks-travelin-soldier-sample',
#   'release_date_components': {'year': 2002, 'month': 7, 'day': 26},
#   'release_date_for_display': 'July 26, 2002',
#   'release_date_with_abbreviated_month_for_display': 'Jul. 26, 2002',
#   'song_art_image_thumbnail_url': 'https://images.genius.com/ad9f3f046b17b05868529aefdb2549c7.300x300x1.jpg',
#   'song_art_image_url': 'https://images.genius.com/ad9f3f046b17b05868529aefdb2549c7.1000x1000x1.jpg',
#   'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 87424},
#   'title': 'Travelin’ Soldier',
#   'title_with_featured': "Travelin' Soldier",
#   'url': 'https://genius.com/The-chicks-travelin-soldier-lyrics',
#   'featured_artists': [],
#   'primary_artist': {'api_path': '/artists/24366',
#    'header_image_url': 'https://images.genius.com/ec7ef9e21398df992cb97508a9888383.1000x333x1.jpg',
#    'id': 24366,
#    'image_url': 'https://images.genius.com/8fed4750f08a5aceea55e3165e00dcca.400x400x1.jpg',
#    'is_meme_verified': False,
#    'is_verified': False,
#    'name': 'The Chicks',
#    'url': 'https://genius.com/artists/The-chicks'}}}

# %%
hits = []
for i in genius_json['response']['hits']:
    hits.append(i['result']['title_with_featured'])

# get top five artist hits 
# exploring
for i in range(0, 5):
    print(hits[i])
# Out:
# Travelin' Soldier
# Gaslighter
# Not Ready to Make Nice
# March March
# Landslide

# %%
songs_list = []
for song in genius_json['response']['hits']:
    songs_list.append([song['result']['title_with_featured'], song['result']['stats']['pageviews'], song['result']['release_date_for_display'], song['result']['song_art_image_url']])

# create dataframe and show only the song title, number of page views, date released, and album cover url for the top five artist hits 
genius_df = pd.DataFrame(songs_list)
genius_df.columns = ['song title', 'page views', 'date released', 'album_cover_url']
genius_df.head(5)
# Out:
#                song title  page views      date released  \
# 0       Travelin' Soldier       87424      July 26, 2002
# 1              Gaslighter      101365      March 4, 2020
# 2  Not Ready to Make Nice       58976     March 24, 2006
# 3             March March       57586      June 25, 2020
# 4               Landslide       31199  September 2, 2002
#
#                                      album_cover_url
# 0  https://images.genius.com/ad9f3f046b17b0586852...
# 1  https://images.genius.com/10068fde15aa8682656d...
# 2  https://images.genius.com/6782708e69d4b6354d61...
# 3  https://images.genius.com/10068fde15aa8682656d...
# 4  https://images.genius.com/5ac3dea65ba38fae3252...

# %%
hit_info = {'Song name':[], 'Page views': [], 'Date released':[]}
for i in genius_json['response']['hits'][:5]:
    hit_info['Song name'].append(i['result']['title'])
    hit_info['Page views'].append(i['result']['stats']['pageviews'])
    hit_info['Date released'].append(i['result']['release_date_for_display'])
hit_info
# create dictionary to prepare to send to .txt file
# Out:
# {'Song name': ['Travelin’ Soldier',
#   'Gaslighter',
#   'Not Ready to Make Nice',
#   'March March',
#   'Landslide'],
#  'Page views': [87424, 101365, 58976, 57586, 31199],
#  'Date released': ['July 26, 2002',
#   'March 4, 2020',
#   'March 24, 2006',
#   'June 25, 2020',
#   'September 2, 2002']}

# %%
def get_html(url):
    # function to get HTML from a url 
    image_html = f"<img src='{url}' width='100px'>"
    return image_html

# %%
genius_df['album cover'] = genius_df['album_cover_url'].apply(get_html)
# send url to get_html function
genius_df.head(5)
# Out:
#                song title  page views      date released  \
# 0       Travelin' Soldier       87424      July 26, 2002
# 1              Gaslighter      101365      March 4, 2020
# 2  Not Ready to Make Nice       58976     March 24, 2006
# 3             March March       57586      June 25, 2020
# 4               Landslide       31199  September 2, 2002
#
#                                      album_cover_url  \
# 0  https://images.genius.com/ad9f3f046b17b0586852...
# 1  https://images.genius.com/10068fde15aa8682656d...
# 2  https://images.genius.com/6782708e69d4b6354d61...
# 3  https://images.genius.com/10068fde15aa8682656d...
# 4  https://images.genius.com/5ac3dea65ba38fae3252...
#
#                                          album cover
# 0  <img src='https://images.genius.com/ad9f3f046b...
# 1  <img src='https://images.genius.com/10068fde15...
# 2  <img src='https://images.genius.com/6782708e69...
# 3  <img src='https://images.genius.com/10068fde15...
# 4  <img src='https://images.genius.com/5ac3dea65b...

# %%
HTML(genius_df[['song title', 'album cover', 'date released', 'page views']].head(5).to_html(escape = False))
# turn HTML into an actual image
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>song title</th>
#       <th>album cover</th>
#       <th>date released</th>
#       <th>page views</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Travelin' Soldier</td>
#       <td><img src='https://images.genius.com/ad9f3f046b17b05868529aefdb2549c7.1000x1000x1.jpg' width='100px'></td>
#       <td>July 26, 2002</td>
#       <td>87424</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Gaslighter</td>
#       <td><img src='https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.1000x1000x1.jpg' width='100px'></td>
#       <td>March 4, 2020</td>
#       <td>101365</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Not Ready to Make Nice</td>
#       <td><img src='https://images.genius.com/6782708e69d4b6354d61e51c6fd7e571.600x528x1.jpg' width='100px'></td>
#       <td>March 24, 2006</td>
#       <td>58976</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>March March</td>
#       <td><img src='https://images.genius.com/10068fde15aa8682656d44e7552a9c0d.1000x1000x1.jpg' width='100px'></td>
#       <td>June 25, 2020</td>
#       <td>57586</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Landslide</td>
#       <td><img src='https://images.genius.com/5ac3dea65ba38fae325250ad95b475c2.512x512x1.jpg' width='100px'></td>
#       <td>September 2, 2002</td>
#       <td>31199</td>
#     </tr>
#   </tbody>
# </table>

# %%
new_df = genius_df[['song title', 'page views', 'date released']]                                                          
new_genius_df = new_df[:5]
new_genius_df
# getting only the stuff I want to export
# Out:
#                song title  page views      date released
# 0       Travelin' Soldier       87424      July 26, 2002
# 1              Gaslighter      101365      March 4, 2020
# 2  Not Ready to Make Nice       58976     March 24, 2006
# 3             March March       57586      June 25, 2020
# 4               Landslide       31199  September 2, 2002

# %%
date_components = []
for i in genius_json['response']['hits'][:5]:
    date_components.append(i['result']['release_date_components'])
date_components
# get the date components (not the date with the written out month)
# Out:
# [{'year': 2002, 'month': 7, 'day': 26},
#  {'year': 2020, 'month': 3, 'day': 4},
#  {'year': 2006, 'month': 3, 'day': 24},
#  {'year': 2020, 'month': 6, 'day': 25},
#  {'year': 2002, 'month': 9, 'day': 2}]

# %%
hit_date_components = []
for i in range(0, 5):
    for value in date_components[i].values():
        hit_date_components.append(value)

components = np.array_split(hit_date_components, 5)
# get just values

# %%
type(components[1][1])
# what type is each component?
# Out:
# numpy.int64

# %%
new_components = []
for i in range(0, 5):
    new_components.append(np.array2string(components[i]))
    # array --> string

new_components2 = []
for item in new_components:
    new_components2.append(item.split())
    # split by commas to facilitate zero padding

# %%
date_objects = []
for i in range(0, len(new_components2)):
    year = new_components2[i][0][1:]
    month = new_components2[i][1]
    day = new_components2[i][2][:-1]
    date_str = month + "-" + day + "-" + year
    date_objects.append(datetime.strptime(date_str, '%m-%d-%Y').date())

date_objects
# list of dates in datetime format to do math on them
# Out:
# [datetime.date(2002, 7, 26),
#  datetime.date(2020, 3, 4),
#  datetime.date(2006, 3, 24),
#  datetime.date(2020, 6, 25),
#  datetime.date(2002, 9, 2)]

# %%
today = datetime.now().date()
# get todays date

# %%
difference_in_days = []
for i in range(0, len(date_objects)):
    difference_in_days.append((today - date_objects[i]).days)
    
difference_in_days # get number of days ago that the song was dropped
# Out:
# [7395, 964, 6058, 851, 7357]

# %%
average_views = []
for i in range(0, len(new_genius_df)):
    average_views.append(new_genius_df['page views'][i] / difference_in_days[i])

new_genius_df['days since release'] = difference_in_days
new_genius_df['views / days since release'] = average_views
new_genius_df.loc[:, ["song title","page views","date released","days since release", "views / days since release"]]
# add new stuff to new_genius_df
# Out:
# <ipython-input-70-94f6c0f8dd38>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_genius_df['days since release'] = difference_in_days
# <ipython-input-70-94f6c0f8dd38>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_genius_df['views / days since release'] = average_views
#                song title  page views      date released  days since release  \
# 0       Travelin' Soldier       87424      July 26, 2002                7395
# 1              Gaslighter      101365      March 4, 2020                 964
# 2  Not Ready to Make Nice       58976     March 24, 2006                6058
# 3             March March       57586      June 25, 2020                 851
# 4               Landslide       31199  September 2, 2002                7357
#
#    views / days since release
# 0                   11.822042
# 1                  105.150415
# 2                    9.735226
# 3                   67.668625
# 4                    4.240723

# %%
print("What format output would you like? Options: csv, sql, json" )
output_format = input()
# Out:
# What format output would you like? Options: csv, sql, json
# csv

# %%
if output_format == 'csv':
    new_genius_df.to_csv('hits.csv', encoding = 'utf-8', index = False)
elif output_format == 'sql':
    con = sqlite3.connect("hits.db")
    cur = con.cursor()
    cur.execute("CREATE TABLE IF NOT EXISTS hits(song_title TEXT, page_views INT, date_released TEXT)")
    con.commit()
    new_genius_df.to_sql('hits', con, if_exists = 'replace', index = False)
    cur.execute('''SELECT * FROM hits''')
    for row in cur.fetchall():
        print(row)
elif output_format == 'json':
    result = new_genius_df.to_json(orient = "split")
    parsed = json.loads(result)
    json_object = json.dumps(parsed, indent = 4)
    with open("hits_as_json.txt", "w") as outfile:
        outfile.write(json_object)
else:
    print("Error: please go back and enter a valid output format!")

# %% [markdown]
# ## DOCUMENTATION: HOW TO USE THIS DATA PROCESSOR

# %% [markdown]
# The purpose of this data processor is to return the top five hits from a music artist based on page views via the Genius API. First, when prompted, please input your client access token to the API, and then enter an artist you'd like to retrieve information about. When this notebook is run, it will return a DataFrame that contains your artist's top five hits' song titles, dates released, page views, number of days since release, and number of page views divided by the days since release. (Note: while rare, you may have issues with some artists because they are either too small or certain things are missing from their Genius profile- this may happen if the artist is older and data is not available for hit release date, for example) At this point, when prompted, please input the output format you would like for the DataFrame.
